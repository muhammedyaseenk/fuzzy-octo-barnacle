# %%
# ! pip install requests

# %%
import requests

url = "http://127.0.0.1:8000/login/"
data = {
    "email": "user@example.com",
    "password": "mypassword"
}
try:
    response = requests.post(url, json=data)
    response.raise_for_status()  # Raises an HTTPError for bad responses
    print(response.json())
except requests.exceptions.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: HTTPConnectionPool(host='127.0.0.1', port=8000): Max retries exceeded with url: /login/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001DFD0A5D0F0>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it'))

# %%
import asyncpg, asyncio

async def test():
    conn = await asyncpg.connect("postgresql://postgres:mysecretpassword@localhost:5432/postgres")
    row = await conn.fetch("SELECT version()")
    print(row)
    await conn.close()
try:
    asyncio.run(test())
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: asyncio.run() cannot be called from a running event loop
# C:\Users\VICTUS\AppData\Local\Temp\ipykernel_416\1040526861.py:11: RuntimeWarning: coroutine 'test' was never awaited
#   print(f"An error occurred: {e}")
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
